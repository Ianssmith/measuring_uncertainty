# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import spearmanr

# %%
df = pd.read_table("data/Well_Visit.txt")
dic = pd.read_table("data/Dictionary.txt")

# %%
pd.set_option('display.max_rows', 999)
pd.set_option('display.max_columns', 999)

# %%
#dic.head
#df.head

# %%
df.arrive = pd.to_datetime(df.arrive)
df.arrive = df.arrive.dt.hour
df = df.sort_values(by='arrive', ascending=0)

# %%
plt.scatter(df.index,df.chaos)
plt.show()

# %%
sns.swarmplot(x=df.arrive, y=df.index, hue=df.global_prof)
plt.show()

# %%
sns.swarmplot(x=df.arrive, y=df.index, hue=df.global_clinic)
plt.show()

# %%
sns.swarmplot(x=df.global_mc, y=df.index, hue=df.arrive)
plt.show()

# %%
sns.swarmplot(x=df.global_clinic, y=df.index, hue=df.arrive)
plt.show()

# %%
sns.swarmplot(x=df.global_prof, y=df.index, hue=df.arrive)
plt.show()

# %%
sns.swarmplot(x=df.global_comm, y=df.index, hue=df.arrive)
plt.show()

# %%
sns.swarmplot(x=df.visit_length, y=df.index, hue=df.global_prof)
plt.show()

# %%
sns.swarmplot(x=df.visit_length, y=df.index, hue=df.global_clinic)
plt.show()

# %%
sns.swarmplot(x=df.visit_waittime, y=df.index, hue=df.global_prof)
#plt.ylim(ymax=200,ymin=0)
plt.show()

# %%
sns.swarmplot(x=df.visit_waittime, y=df.index, hue=df.global_clinic)
#plt.ylim(ymax=200,ymin=0)
plt.show()

# %%
sns.swarmplot(x=df.global_mc, y=df.visit_length)
plt.show()

# %%
sns.swarmplot(x=df.global_comm, y=df.visit_length)
plt.show()

# %%
sns.swarmplot(x=df.global_prof, y=df.visit_length)
plt.show()

# %%
sns.swarmplot(x=df.global_clinic, y=df.visit_length)
plt.show()

# %%
sns.swarmplot(x=df.global_mc, y=df.chaos)
plt.show()

# %%
sns.swarmplot(x=df.global_mc, y=df.visit_length)
plt.title("Visit length (min) vs overall medical competence rating 0-3")
plt.ylim(ymax=300,ymin=-50)
plt.show()

# %%
sns.swarmplot(x=df.global_mc, y=df.visit_waittime)
plt.title("Visit length (min) vs overall clinic rating 0-3")
plt.show()

# %%
sns.swarmplot(x=df.global_mc, y=df.visit_waittime)
plt.title("Visit wait time (min) vs overall medical competence rating 0-3")
plt.ylim(ymax=350,ymin=-50)
plt.show()

# %%
sns.swarmplot(x=df.global_clinic, y=df.visit_waittime)
plt.title("Visit wait time (min) vs overall clinic rating 0-3")
plt.show()

# %%
sns.swarmplot(x=df.global_clinic, y=df.visit_length)
plt.title("Visit length (min) vs overall clinic rating 0-3")
plt.ylim(ymax=350,ymin=-50)
plt.show()

# %%
sns.swarmplot(x=df.global_prof, y=df.visit_waittime)
plt.title("Visit wait time (min) vs overall professionalism rating 0-3")
plt.show()

# %%
sns.swarmplot(x=df.global_prof, y=df.visit_length)
plt.title("Visit length (min) vs overall professionalism rating 0-3")
plt.ylim(ymax=350,ymin=-50)
plt.show()

# %%
sns.swarmplot(x=df.visit_length, y=df.chaos, hue=df.chaos)
plt.title("Visit length (min) vs chaos")
plt.xlim(xmax=70,xmin=-20)
plt.show()

# %%
sns.swarmplot(x=df.visit_waittime, y=df.chaos, hue=df.chaos)
plt.title("Visit wait time (min) vs 'chaos'")
plt.xlim(xmax=70,xmin=-20)
plt.show()

# %%
sns.swarmplot(x=df.visit_waittime, y=df.visit_length, hue=df.chaos)
plt.title("Visit length (min) vs waittime color coded by 'chaos rating'")
plt.ylim(ymax=350,ymin=-50)
plt.xlim(xmax=70,xmin=-10)
plt.show()

# %%
sns.swarmplot(x=df.global_comm, y=df.visit_length, hue=df.arrive)
plt.title("Visit length (min) vs overall communication rating 0-3")
plt.ylim(ymax=350,ymin=-50)
plt.show()

# %%
sns.swarmplot(x=df.global_clinic, y=df.visit_length, hue=df.arrive)
plt.title("Visit length (min) vs overall clinic rating 0-3")
plt.ylim(ymax=350,ymin=-50)
plt.show()

# %%
sns.jointplot('global_mc','chaos', data=df, kind="reg")
plt.show()
# Out:
# /Applications/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.jointplot('global_clinic','chaos', data=df, kind="reg")
plt.show()
# Out:
# /Applications/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.jointplot('global_comm','chaos', data=df, kind="reg")
plt.show()
# Out:
# /Applications/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.jointplot('global_mc','visit_waittime', data=df, kind="reg")
plt.ylim(ymax=150, ymin=0)
plt.show()
# Out:
# /Applications/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.jointplot('global_mc','visit_length', data=df, kind="reg")
plt.ylim(ymax=150, ymin=0)
plt.show()
# Out:
# /Applications/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.jointplot('global_prof','visit_length', data=df, kind="reg")
plt.ylim(ymax=200, ymin=0)
plt.show()
# Out:
# /Applications/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.jointplot('global_prof','visit_waittime', data=df, kind="reg")
plt.ylim(ymax=150, ymin=0)
plt.show()
# Out:
# /Applications/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.jointplot('visit_length','visit_waittime', data=df, kind="reg")
plt.ylim(ymax=150, ymin=0)
plt.show()
# Out:
# /Applications/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.jointplot('global_clinic','visit_waittime', data=df, kind="reg")
plt.ylim(ymax=150, ymin=0)
plt.show()
# Out:
# /Applications/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
#******
sns.jointplot('global_clinic','visit_length', data=df, kind="reg")
plt.ylim(ymax=200, ymin=0)
plt.show()
# Out:
# /Applications/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.jointplot('arrive','global_clinic', data=df, kind="reg")
plt.xlim(xmax=16,xmin=6)
plt.show()
# Out:
# /Applications/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.jointplot('arrive','global_mc', data=df, kind="reg")
plt.xlim(xmax=16,xmin=6)
plt.show()
# Out:
# /Applications/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.jointplot('arrive','global_prof', data=df, kind="reg")
plt.xlim(xmax=16,xmin=6)
plt.show()
# Out:
# /Applications/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.jointplot('arrive','global_comm', data=df, kind="reg")
plt.title("Arrival time vs Overall communication score 0-3")
plt.xlim(xmax=16,xmin=6)
plt.show()
# Out:
# /Applications/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
#conclusive plots VVVVV

# %%
sns.jointplot('global_prof','visit_length', data=df, kind="reg")
plt.ylim(ymax=200, ymin=0)
plt.show()
# Out:
# /Applications/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
plt.subplot(1,2,1)
sns.swarmplot(x=df.global_prof, y=df.visit_length)
plt.title("Visit length (min) vs overall professionalism rating 0-3")
plt.ylim(ymax=350,ymin=-50)
plt.subplot(1,2,2)
sns.swarmplot(x=df.visit_length, y=df.index, hue=df.global_prof)
plt.show()

# %%
sns.jointplot('global_clinic','visit_length', data=df, kind="reg")
plt.ylim(ymax=200, ymin=0)
plt.show()
# Out:
# /Applications/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
plt.subplot(1,2,1)
sns.swarmplot(x=df.global_clinic, y=df.visit_length)
plt.title("Visit wait time (min) vs overall clinic rating 0-3")
plt.ylim(ymax=350,ymin=-50)
plt.subplot(1,2,2)
sns.swarmplot(x=df.visit_length, y=df.index, hue=df.global_clinic)
plt.show()

# %%
#looks like overfitting to me
